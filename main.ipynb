# %%
import PortfolioAnalysis as pfa

# %%
import pandas as pd 
import numpy as np 
from pandas_datareader import data
import matplotlib.pyplot as plt
plt.style.use("fivethirtyeight")
# Out:
# c:\python38\lib\site-packages\pandas_datareader\compat\__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %%
## start and end of time period
start_date = '2019-02-01'
end_date = '2020-01-31'
## 5 Stock Tickers
ticker = ['AMZN', "FB", "QCOM", "CSCO", "TSLA"]
## Download the data
df = data.get_data_yahoo(ticker, start_date, end_date)["Close"]
df.to_csv("data.csv")
df.head()
# Out:
# Symbols            AMZN          FB       QCOM       CSCO        TSLA
# Date
# 2019-01-31  1718.729980  166.690002  49.520000  47.290001  307.019989
# 2019-02-01  1626.229980  165.710007  49.610001  47.340000  312.209991
# 2019-02-04  1633.310059  169.250000  49.689999  47.349998  312.890015
# 2019-02-05  1658.810059  171.160004  50.730000  47.259998  321.350006
# 2019-02-06  1640.260010  170.490005  51.099998  47.480000  317.220001

# %%
model = pfa.PortFolAnalysis(df)

# %%
help(model.random_portfolios)
# Out:
# Help on method random_portfolios in module PortfolioAnalysis:
#
# random_portfolios(num_portfolios=1000, risk_free_rate=0.0178) method of PortfolioAnalysis.PortFolAnalysis instance

# %%
model.random_portfolios(5000, 0.018)
# Out:
# 5000 3
# Weigths of minimum volatility portfolio are:  [0.39068436 0.20353735 0.038113   0.33921525 0.02845004]  and value of volatility is:  0.17992140376869958
# Weigths of maximum return portfolio are:  [8.26133416e-05 1.77266731e-08 7.53513219e-04 3.46537750e-06
#  9.99160390e-01]   and return is:  0.8716778721025334
# Weigths of maximum sharpe portfolio are:  [4.79989237e-04 1.01689101e-01 4.42216040e-01 1.95513371e-07
#  4.55614675e-01]   and sharpe is:  2.10538945047946

# %%
model.Optimal_weights(0.4)
# Out:
# 5
# Optimal portfolio
# ----------------------
#  Investment in AMZN : 30.69% of the portfolio
#  Investment in FB : 26.69% of the portfolio
#  Investment in QCOM : 20.99% of the portfolio
#  Investment in CSCO : 3.86% of the portfolio
#  Investment in TSLA : 17.77% of the portfolio
# ----------------------
# Exp ret = 40.0%
# Expected risk    = 20.9%
# (array([0.30689252, 0.26689986, 0.20987953, 0.03862397, 0.17770412]),
#  0.04366380150432716)
